# %% [markdown]
# # 1. Constants

# %% [markdown]
# [example data](http://cseweb.ucsd.edu/~viscomp/projects/LF/papers/ECCV20/nerf/nerf_example_data.zip)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/cs117/final project/nerf_pytorch')

# %% [markdown]
# ## 1.1 Imports

# %%
from run_nerf import train, generate_render
import argparse

# %% [markdown]
# # 2. Train

# %%
train_args = argparse.Namespace(
        basedir='/content/drive/My Drive/cs117/final project/nerf_pytorch/logs',  # Where to store ckpts and logs
        datadir='/content/drive/My Drive/cs117/final project/nerf_pytorch/data/nerf_synthetic/lego',  # Input data directory
        config='/content/drive/My Drive/cs117/final project/nerf_pytorch/configs/lego.txt',  # Config file path
        ft_path= '/content/drive/My Drive/cs117/final project/nerf_pytorch/logs/blender_paper_lego/036000.tar',       # Specific weights tar file to reload for coarse network

        dataset_type='blender',  # Default: 'llff', Dataset type (options: llff / blender / deepvoxels)
        expname='blender_paper_lego',  # Default: None, Experiment name

        N_iters=100001,       # Default: 200000, Number of iterations (training steps)
        i_img=999999999,         # Default: 500, Frequency of tensorboard image logging
        i_print=100,        # Default: 100, Frequency of console printout and metric logging
        i_weights= 1000,     # Default: 10000, Frequency of weight ckpt saving

        half_res=False,     # Default: False, Load blender synthetic data at 400x400 instead of 800x800
    )

# %%
train(train_args)

# %% [markdown]
# # 3. Render Images / Video

# %%
render_args = argparse.Namespace(

        basedir='/content/drive/My Drive/cs117/final project/nerf_pytorch/logs',  # Where to store ckpts and logs
        datadir='/content/drive/My Drive/cs117/final project/nerf_pytorch/data/nerf_synthetic/lego',  # Input data directory
        config='/content/drive/My Drive/cs117/final project/nerf_pytorch/configs/lego.txt',  # Config file path
        ft_path= '/content/drive/My Drive/cs117/final project/nerf_pytorch/logs/blender_paper_lego/036000.tar',       # Specific weights tar file to reload for coarse network
        dataset_type='blender',  # Default: 'llff', Dataset type (options: llff / blender / deepvoxels)
        expname='blender_paper_lego',  # Default: None, Experiment name
        half_res=False,     # Default: False, Load blender synthetic data at 400x400 instead of 800x800
        num_frames = 10,    # Default: 40, Number of frames generated
    )

# %%
generate_render(render_args)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:1144: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Loaded blender (138, 800, 800, 4) torch.Size([10, 4, 4]) [800, 800, 1111.1110311937682] /content/drive/My Drive/cs117/final project/nerf_pytorch/data/nerf_synthetic/lego
# ...
